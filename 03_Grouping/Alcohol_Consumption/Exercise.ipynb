# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby("continent").agg({'beer_servings' : 'mean'}).idxmax()
# Out:
# beer_servings    EU
# dtype: object

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby("continent").agg({'wine_servings' : 'sum', 'total_litres_of_pure_alcohol' : 'sum'})
# Out:
#            wine_servings  total_litres_of_pure_alcohol
# continent
# AF                   862                         159.4
# AS                   399                          95.5
# EU                  6400                         387.8
# OC                   570                          54.1
# SA                   749                          75.7

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby(["continent", "country"]).agg({
    'wine_servings' : 'mean', 
    'total_litres_of_pure_alcohol' : 'mean', 
    'beer_servings' : 'mean',
    'spirit_servings' : 'mean'
    })
# Out:
#                         wine_servings  total_litres_of_pure_alcohol  \
# continent country
# AF        Algeria                14.0                           0.7
#           Angola                 45.0                           5.9
#           Benin                  13.0                           1.1
#           Botswana               35.0                           5.4
#           Burkina Faso            7.0                           4.3
# ...                               ...                           ...
# SA        Paraguay               74.0                           7.3
#           Peru                   21.0                           6.1
#           Suriname                7.0                           5.6
#           Uruguay               220.0                           6.6
#           Venezuela               3.0                           7.7
#
#                         beer_servings  spirit_servings
# continent country
# AF        Algeria                25.0              0.0
# ...

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby(["continent", "country"]).agg({
    'wine_servings' : 'mean', 
    'total_litres_of_pure_alcohol' : 'median', 
    'beer_servings' : 'mean',
    'spirit_servings' : 'mean'
    })
# Out:
#                         wine_servings  total_litres_of_pure_alcohol  \
# continent country
# AF        Algeria                14.0                           0.7
#           Angola                 45.0                           5.9
#           Benin                  13.0                           1.1
#           Botswana               35.0                           5.4
#           Burkina Faso            7.0                           4.3
# ...                               ...                           ...
# SA        Paraguay               74.0                           7.3
#           Peru                   21.0                           6.1
#           Suriname                7.0                           5.6
#           Uruguay               220.0                           6.6
#           Venezuela               3.0                           7.7
#
#                         beer_servings  spirit_servings
# continent country
# AF        Algeria                25.0              0.0
# ...

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
# drinks[drinks["spirit_servings"] == drinks["spirit_servings"].min()]
drinks["spirit_servings"].min()
# Out:
# 0

# %%
# drinks[drinks["spirit_servings"] == drinks["spirit_servings"].max()]
drinks["spirit_servings"].max()
# Out:
# 438

# %%
# drinks[drinks["spirit_servings"] == drinks["spirit_servings"].mean()]
drinks["spirit_servings"].mean()
# Out:
# 80.99481865284974

# %%
drinks.groupby('continent')["spirit_servings"].agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302
